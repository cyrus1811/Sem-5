# %%
import pandas as pd
import requests
from urllib.parse import urlencode
import csv

def fetch_single_spectrum():
    base_url = "https://exoplanetarchive.ipac.caltech.edu/TAP/sync"
    query = "SELECT * FROM spectra"
    params = {"query": query, "format": "csv"}
    url = f"{base_url}?{urlencode(params)}"

    try:
        df = pd.read_csv(url)
        print(df.head())  # Debugging: Print metadata preview

        base_data_url = "https://exoplanetarchive.ipac.caltech.edu/workspace/TMP_0S5fAs_13661/atmospheres/tab1/data/"
        csv_filename = "MyData.csv"

        with open(csv_filename, mode="w", newline="") as file:
            writer = csv.writer(file)
            header_written = False  # Track if the header has been written

            for spec_path in df['spec_path']:
                full_url = f"{base_data_url}{spec_path}"
                print(f"Downloading {full_url}")  # Debugging: Print the full URL

                response = requests.get(full_url)

                if response.status_code == 200:
                    content = response.text.split("\n")

                    for line in content:
                      if line.startswith("\\PL_NAME"):
                        planet_name = line.split("=")[1].strip()
                        break
                    table_lines = [line.strip() for line in content if not "\\" in line]
                    print(table_lines)

                    # Find the **first real data row** by ignoring headers, types, and units
                    data_start_index = -1
                    for i, line in enumerate(table_lines):
                        if "microns" in line or "Jupiter radii" in line or "days" in line:  # This row is just units, skip it
                            continue
                        if "double" in line or "char" in line or "null" in line:  # Data types and placeholders, skip them
                            continue
                        data_start_index = i
                        break  # Found first valid data row

                    if data_start_index == -1:
                        raise ValueError("Error: No valid data rows found!")

                    # Extract headers (before the first data row)
                    header = ["PL_NAME"] + [col.strip() for col in table_lines[data_start_index].split("|") if col.strip()]

                    # Write header only once
                    if not header_written:
                        writer.writerow(header)
                        header_written = True

                    for j in range(data_start_index + 4, len(table_lines)):
                        temp_data = [col.strip() for col in table_lines[j].split(" ") if col.strip()]
                        data = []
                        i = 0
                        while i < len(temp_data):
                            if "et" in temp_data[i]:
                                # Merge author name parts
                                data.append(temp_data[i-1] + " " + temp_data[i] + " " + temp_data[i+1] + " " + temp_data[i+2])
                                data.remove(temp_data[i-1])
                                i += 2
                            elif temp_data[i].startswith("http"):
                                data.append(temp_data[i])
                            else:
                                data.append(temp_data[i])
                            i += 1

                        print(data)

                        # Ensure the data row has the same length as the header
                        if len(data) != len(header):
                          print(f"Warning: Data row length ({len(data)}) and header length ({len(header)}) do not match.")

                          if len(data) > len(header):
                              data = data[:len(header)]  # Trim excess values
                          else:
                              data += [""] * (len(header) - len(data))  # Pad with empty strings

                        writer.writerow([planet_name] + data)  # Writing all rows properly
                        print("Data row appended successfully.")

                else:
                    print(f"Failed to download. HTTP Status: {response.status_code}")

        print(f"Data successfully written to {csv_filename}")

    except Exception as e:
        print(f"Error fetching data: {e}")

# Example usage
fetch_single_spectrum()
# Out:
# Streaming output truncated to the last 5000 lines.
# Data row appended successfully.
# ['2.06425', '0.00098', '1.18116', '0.03745', '-0.03745', '0', 'Louie et al. 2025', 'https://ui.adsabs.harvard.edu/abs/2025AJ....169...86L/abstract', '0.10868', '0.00171', '-0.00174', '1', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '1.5758', '0.2025', '-0.2025', '0', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '2460024.197422', '0.000019', '-0.000019', '0', '1.4900', '0.1900', '-0.1900', 'Stassun et al. 2017', 'https://ui.adsabs.harvard.edu/abs/2017AJ....153..136S/abstract']
# Warning: Data row length (29) and header length (30) do not match.
# Data row appended successfully.
# ['2.06524', '0.00098', '1.16585', '0.03805', '-0.03805', '0', 'Louie et al. 2025', 'https://ui.adsabs.harvard.edu/abs/2025AJ....169...86L/abstract', '0.10797', '0.00175', '-0.00178', '1', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '1.5656', '0.2013', '-0.2013', '0', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '2460024.197422', '0.000019', '-0.000019', '0', '1.4900', '0.1900', '-0.1900', 'Stassun et al. 2017', 'https://ui.adsabs.harvard.edu/abs/2017AJ....153..136S/abstract']
# Warning: Data row length (29) and header length (30) do not match.
# Data row appended successfully.
# ['2.06622', '0.00098', '1.15287', '0.03769', '-0.03769', '0', 'Louie et al. 2025', 'https://ui.adsabs.harvard.edu/abs/2025AJ....169...86L/abstract', '0.10737', '0.00174', '-0.00177', '1', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '1
'0', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '2460024.197422', '0.000019', '-0.000019', '0', '1.4900', '0.1900', '-0.1900', 'Stassun et al. 2017', 'https://ui.adsabs.harvard.edu/abs/2017AJ....153..136S/abstract']
# Warning: Data row length (29) and header length (30) do not match.
# Data row appended successfully.
# ['2.14110', '0.00099', '1.49849', '0.05430', '-0.05430', '0', 'Louie et al. 2025', 'https://ui.adsabs.harvard.edu/abs/2025AJ....169...86L/abstract', '0.12241', '0.00220', '-0.00224', '1', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '1.7749', '0.2286', '-0.2286', '0', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '2460024.197422', '0.000019', '-0.000019', '0', '1.4900', '0.1900', '-0.1900', 'Stassun et al. 2017', 'https://ui.adsabs.harvard.edu/abs/2017AJ....153..136S/abstract']
# Warning: Data row length (29) and header length (30) do not match.
# Data row appended successfully.
# ...
# ['10.57500', 'null', '8.6000000000000004612e-19', '1.7000000000000001024e-19', '-1.7000000000000001024e-19', '0', 'null', 'null', 'null', '5573', '2024A&A...690A.316M', '<a', 'refstr=M_AMP_ACIRC_LIN_ET_AL__2024', 'href=https://ui.adsabs.harvard.edu/abs/2024A&A...690A.316M/abstract target=ref>M&acirc;lin et al.', '2024</a>', 'M&acirc;lin et al. 2024', 'https://ui.adsabs.harvard.edu/abs/2024A&A...690A.316M/abstract', '3.207949883255503112e-05', '6.341296280853903037e-06', '-6.341296280853903037e-06', '0', '6.341296280853903e-06', '-6.341296280853903e-06', 'null', 'Calculated', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '2460019.645833', 'null', 'null']
# Warning: Data row length (32) and header length (30) do not match.
# Data row appended successfully.
# ['11.30000', 'null', '6.3000000000000001811e-19', '7.9999999999999995612e-20', '-7.9999999999999995612e-20', '0', 'null', 'null', 'null', '5573', '2024A&A...690A.316M', '<a', 'refstr=M_AMP_ACIRC_LIN_ET_AL__2024', 'href=https://ui.adsabs.harvard.edu/abs/2024A&A...690A.316M/abstract target=ref>M&acirc;lin et al.', '2024</a>', 'M&acirc;lin et al. 2024', 'https://ui.adsabs.harvard.edu/abs/2024A&A...690A.316M/abstract', '2.6832788525683794206e-05', '3.4073382254836562726e-06', '-3.4073382254836562726e-06', '0', '3.4073382254836563e-06', '-3.4073382254836563e-06', 'null', 'Calculated', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '2460019.681944', 'null', 'null']
# Warning: Data row length (32) and header length (30) do not match.
# Data row appended successfully.
# []
# Warning: Data row length (0) and header length (30) do not match.
# Data row appended successfully.
# Downloading https://exoplanetarchive.ipac.caltech.edu/workspace/TMP_0S5fAs_13661/atmospheres/tab1/data/47/82/20/61/WASP_19_b_3.11448_5574_1.tbl
# ['|CENTRALWAVELNG|BANDWIDTH|ESPECLIPDEP|ESPECLIPDEPERR1|ESPECLIPDEPERR2|ESPECLIPDEPLIM|ESPBRITEMP|ESPBRITEMPERR1|ESPBRITEMPERR2|ESPBRITEMPLIM|      OBS_DATE|OBS_DATEERR1|OBS_DATEERR2|', '|        double|   double|     double|         double|         double|          char|    double|        double|        double|         long|          char|        char|        char|', '|       microns|  microns|          %|               |               |              |         K|              |              |             |          days|        days|        days|', '|          null|     null|       null|           null|           null|          null|      null|          null|          null|         null|          null|        null|        null|', '1.17520   0.08250     0.10900         0.01800        -0.01600           null       null           null           null             0 2456819.613679         null         null', '1.25770   0.08260     0.14300         0.02500        -0.02700           null       null           null           null             0 2456819.613679         null         null', '1.34260   0.08710     0.13300         0.01500        -0.01200           null       null           null           null             0 2456819.613679         null         null', '1.42740   0.08250     0.12400         0.01800        -0.01600           null       null           null           null             0 2456819.613679         null         null', '1.50990   0.08260     0.17400         0.01800        -0.01800           null       null           null           null             0 2456819.613679         null         null', '1.59480   0.08710     0.17500         0.01700        -0.01600           null       null           null           null             0 2456819.613679         null         null', '']
# ['1.17520', '0.08250', '0.10900', '0.01800', '-0.01600', 'null', 'null', 'null', 'null', '0', '2456819.613679', 'null', 'null']
# Warning: Data row length (13) and header length (14) do not match.
# Data row appended successfully.
# ['1.25770', '0.08260', '0.14300', '0.02500', '-0.02700', 'null', 'null', 'null', 'null', '0', '2456819.613679', 'null', 'null']
# Warning: Data row length (13) and header length (14) do not match.
# Data row appended successfully.
# ['1.34260', '0.08710', '0.13300', '0.01500', '-0.01200', 'null', 'null', 'null', 'null', '0', '2456819.613679', 'null', 'null']
# Warning: Data row length (13) and header length (14) do not match.
# Data row appended successfully.
# ['1.42740', '0.08250', '0.12400', '0.01800', '-0.01600', 'null', 'null', 'null', 'null', '0', '2456819.613679', 'null', 'null']
# Warning: Data row length (13) and header length (14) do not match.
# Data row appended successfully.
# ['1.50990', '0.08260', '0.17400', '0.01800', '-0.01800', 'null', 'null', 'null', 'null', '0', '2456819.613679', 'null', 'null']
# Warning: Data row length (13) and header length (14) do not match.
# Data row appended successfully.
# ['1.59480', '0.08710', '0.17500', '0.01700', '-0.01600', 'null', 'null', 'null', 'null', '0', '2456819.613679', 'null', 'null']
# Warning: Data row length (13) and header length (14) do not match.
# Data row appended successfully.
# []
# Warning: Data row length (0) and header length (14) do not match.
# Data row appended successfully.
# Downloading https://exoplanetarchive.ipac.caltech.edu/workspace/TMP_0S5fAs_13661/atmospheres/tab1/data/76/39/42/03/WASP_19_b_3.11448_5574_3.tbl
# ['|CENTRALWAVELNG|BANDWIDTH|PL_TRANDEP|PL_TRANDEPERR1|PL_TRANDEPERR2|PL_TRANDEPLIM|PL_TRANDEP_AUTHORS|                         PL_TRANDEP_URL|PL_RATROR|PL_RATRORERR1|PL_RATRORERR2|PL_RATRORLIM|    PL_RATROR_AUTHORS|                                                 PL_RATROR_URL|      PL_RADJ|PL_RADJERR1|PL_RADJERR2|PL_RADJLIM|PL_RADJ_AUTHORS|                            PL_RADJ_URL|    PL_TRANMID|PL_TRANMIDERR1|PL_TRANMIDERR2|PL_TRANMIDLIM|     ST_RAD|ST_RADERR1|ST_RADERR2|                  ST_RAD_AUTHORS|                                                    ST_RAD_URL|', '|        double|   double|    double|        double|        double|         long|              char|                                   char|   double|       double|       double|        long|                 char|                                                          char|       double|     double|     double|      long|           char|                                   char|        double|        double|        double|         long|     double|    double|    double|                            char|                                                          char|', '|       microns|  microns|         %|              |              |             |                  |                                       |         |             |             |            |                     |                                                              |Jupiter radii|           |           |          |               |                                       |          days|              |              |             |solar radii|          |          |                                |                                                              |', '|          null|     null|      null|          null|          null|         null|              null|                                   null|     null|         null|         null|        null|                 null|                                                          null|         null|       null|       null|      null|           null|                                   null|          null|          null|          null|         null|       null|      null|      null|                            null|                                                          null|', '1.17440   0.08260    2.09034        0.02203       -0.02221             0         Calculated /docs/atmospheres/atmospheres_calc.html   0.14458       0.00076      -0.00077            0 Tumborang et al. 2024 https://ui.adsabs.harvard.edu/abs/2024AJ....168..296T/abstract        1.4154      0.0463     -0.0463          0      Calculated /docs/atmospheres/atmospheres_calc.html 2456820.796002           null           null             0      1.0060     0.0310    -0.0340 Cort&eacute;s-Zuleta et al. 2020 https://ui.adsabs.harvard.edu/abs/2020A&A...636A..98C/abstract', '1.25700   0.08250    2.08052        0.01474       -0.01612             0         Calculated /docs/atmospheres/atmospheres_calc.html   0.14424       0.00051      -0.00056            0 Tumborang et al. 2024 https://ui.adsabs.harvard.edu/abs/2024AJ....168..296T/abstract        1.4120      0.0459     -0.0459          0      Calculated /docs/atmospheres/atmospheres_calc.html 2456820.796002           null           null             0      1.0060     0.0310    -0.0340 Cort&eacute;s-Zuleta et al. 2020 https://ui.adsabs.harvard.edu/abs/2020A&A...636A..98C/abstract', '1.34180   0.08710    2.09410        0.02962       -0.01733             0         Calculated /docs/atmospheres/atmospheres_calc.html   0.14471       0.00102      -0.00060            0 Tumborang et al. 2024 https://ui.adsabs.harvard.edu/abs/2024AJ....168..296T/abstract        1.4166      0.0464     -0.0464          0      Calculated /docs/atmospheres/atmospheres_calc.html 2456820.796002           null           null             0      1.0060     0.0310    -0.0340 Cort&eacute;s-Zuleta et al. 2020 https://ui.adsabs.harvard.edu/abs/2020A&A...636A..98C/abstract', '1.42660 ...
# ['1.17440', '0.08260', '2.09034', '0.02203', '-0.02221', '0', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '0.14458', '0.00076', '-0.00077', '0', 'Tumborang et al. 2024', 'https://ui.adsabs.harvard.edu/abs/2024AJ....168..296T/abstract', '1.4154', '0.0463', '-0.0463', '0', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '2456820.796002', 'null', 'null', '0', '1.0060', '0.0310', '-0.0340 Cort&eacute;s-Zuleta et al.', '2020', 'https://ui.adsabs.harvard.edu/abs/2020A&A...636A..98C/abstract']
# Warning: Data row length (29) and header length (30) do not match.
# Data row appended successfully.
# ['1.25700', '0.08250', '2.08052', '0.01474', '-0.01612', '0', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '0.14424', '0.00051', '-0.00056', '0', 'Tumborang et al. 2024', 'https://ui.adsabs.harvard.edu/abs/2024AJ....168..296T/abstract', '1.4120', '0.0459', '-0.0459', '0', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '2456820.796002', 'null', 'null', '0', '1.0060', '0.0310', '-0.0340 Cort&eacute;s-Zuleta et al.', '2020', 'https://ui.adsabs.harvard.edu/abs/2020A&A...636A..98C/abstract']
# Warning: Data row length (29) and header length (30) do not match.
# Data row appended successfully.
# ['1.34180', '0.08710', '2.09410', '0.02962', '-0.01733', '0', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '0.14471', '0.00102', '-0.00060', '0', 'Tumborang et al. 2024', 'https://ui.adsabs.harvard.edu/abs/2024AJ....168..296T/abstract', '1.4166', '0.0464', '-0.0464', '0', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '2456820.796002', 'null', 'null', '0', '1.0060', '0.0310', '-0.0340 Cort&eacute;s-Zuleta et al.', '2020', 'https://ui.adsabs.harvard.edu/abs/2020A&A...636A..98C/abstract']
# Warning: Data row length (29) and header length (30) do not match.
# Data row appended successfully.
# ['1.42660', '0.08260', '2.13131', '0.02401', '-0.02591', '0', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '0.14599', '0.00082', '-0.00089', '0', 'Tumborang et al. 2024', 'https://ui.adsabs.harvard.edu/abs/2024AJ....168..296T/abstract', '1.4292', '0.0469', '-0.0469', '0', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '2456820.796002', 'null', 'null', '0', '1.0060', '0.0310', '-0.0340 Cort&eacute;s-Zuleta et al.', '2020', 'https://ui.adsabs.harvard.edu/abs/2020A&A...636A..98C/abstract']
# Warning: Data row length (29) and header length (30) do not match.
# Data row appended successfully.
# ['1.50920', '0.08250', '2.14916', '0.01910', '-0.02193', '0', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '0.14660', '0.00065', '-0.00075', '0', 'Tumborang et al. 2024', 'https://ui.adsabs.harvard.edu/abs/2024AJ....168..296T/abstract', '1.4351', '0.0469', '-0.0469', '0', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '2456820.796002', 'null', 'null', '0', '1.0060', '0.0310', '-0.0340 Cort&eacute;s-Zuleta et al.', '2020', 'https://ui.adsabs.harvard.edu/abs/2020A&A...636A..98C/abstract']
# Warning: Data row length (29) and header length (30) do not match.
# Data row appended successfully.
# ['1.59400', '0.08710', '2.09178', '0.02932', '-0.01818', '0', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '0.14463', '0.00101', '-0.00063', '0', 'Tumborang et al. 2024', 'https://ui.adsabs.harvard.edu/abs/2024AJ....168..296T/abstract', '1.4159', '0.0464', '-0.0464', '0', 'Calculated', '/docs/atmospheres/atmospheres_calc.html', '2456820.796002', 'null', 'null', '0', '1.0060', '0.0310', '-0.0340 Cort&eacute;s-Zuleta et al.', '2020', 'https://ui.adsabs.harvard.edu/abs/2020A&A...636A..98C/abstract']
# Warning: Data row length (29) and header length (30) do not match.
# Data row appended successfully.
# []
# Warning: Data row length (0) and header length (30) do not match.
# Data row appended successfully.
# Downloading https://exoplanetarchive.ipac.caltech.edu/workspace/TMP_0S5fAs_13661/atmospheres/tab1/data/97/09/53/21/WASP_19_b_3.11448_5574_2.tbl
# ['|CENTRALWAVELNG|BANDWIDTH|ESPECLIPDEP|ESPECLIPDEPERR1|ESPECLIPDEPERR2|ESPECLIPDEPLIM|ESPBRITEMP|ESPBRITEMPERR1|ESPBRITEMPERR2|ESPBRITEMPLIM|OBS_DATE|OBS_DATEERR1|OBS_DATEERR2|', '|        double|   double|     double|         double|         double|          char|    double|        double|        double|         long|    char|        char|        char|', '|       microns|  microns|          %|               |               |              |         K|              |              |             |    days|        days|        days|', '|          null|     null|       null|           null|           null|          null|      null|          null|          null|         null|    null|        null|        null|', '3.60000   0.37500     0.48500         0.02400        -0.02400           null       null           null           null             0     null         null         null', '4.50000   0.50750     0.58400         0.02900        -0.02900           null       null           null           null             0     null         null         null', '5.80000   0.70000     0.65000         0.01100        -0.01100           null       null           null           null             0     null         null         null', '8.00000   1.45000     0.73000         0.01200        -0.01200           null       null           null           null             0     null         null         null', '']
# ['3.60000', '0.37500', '0.48500', '0.02400', '-0.02400', 'null', 'null', 'null', 'null', '0', 'null', 'null', 'null']
# Warning: Data row length (13) and header length (14) do not match.
# Data row appended successfully.
# ['4.50000', '0.50750', '0.58400', '0.02900', '-0.02900', 'null', 'null', 'null', 'null', '0', 'null', 'null', 'null']
# Warning: Data row length (13) and header length (14) do not match.
# Data row appended successfully.
# ['5.80000', '0.70000', '0.65000', '0.01100', '-0.01100', 'null', 'null', 'null', 'null', '0', 'null', 'null', 'null']
# Warning: Data row length (13) and header length (14) do not match.
# Data row appended successfully.
# ['8.00000', '1.45000', '0.73000', '0.01200', '-0.01200', 'null', 'null', 'null', 'null', '0', 'null', 'null', 'null']
# Warning: Data row length (13) and header length (14) do not match.
# Data row appended successfully.
# []
# Warning: Data row length (0) and header length (14) do not match.
# Data row appended successfully.
# Data successfully written to MyData.csv
